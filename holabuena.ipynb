# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/MyDrive/prueba_setup.txt','w') as f:
    f.write('Hola mi entorno de Colab y drive está conectado correctamente!')
print('guardado en Drive con éxito')
# Out:
# guardado en Drive con éxito
